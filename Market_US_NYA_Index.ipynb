# %% [markdown]
# #Analysis of the US market in Market.csv dataset by NYA Index based on open and close candle parameters, candle close price, volume

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates
#baraye tarsime sotunhaye date be surate time seris
import seaborn as sns
import math
import datetime
from matplotlib import dates as mpl_dates
import matplotlib.dates as mdates

# %%
from datetime import datetime

# %%
Data = pd.read_csv('Market.csv')        #load dataset
# dakhele data yek dataframe dorost mikonom k sari update beshe dar datafarame
Data = pd.DataFrame(Data)
Data
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
# hazf baghye shakhesha joz NYA

# %%
Data1=Data.iloc[:13948]
Data1
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
#sotunha chanta mising valu dare
print ("\n show the missing values of DataFrame : \n\n", Data1.isnull().sum())
# Out:
#  show the missing values of DataFrame :
#
#  Index         0
# Date          0
# Open          1
# High          2
# Low           3
# Close         4
# Adj Close    10
# Volume        1
# dtype: int64

# %%
# hazf mising value

# %%
Data2 = Data1.dropna()
Data2
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
# tabdil float be integer

# %%
Data2 = Data2.applymap(lambda x: int(round(x, 0)) if isinstance(x, (int, float)) else x)
Data2
# Out:
#       Index        Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA  12/31/1965    529    529    529    529        529           0
# 1       NYA    1/3/1966    527    527    527    527        527           0
# 2       NYA    1/4/1966    528    528    528    528        528           0
# 3       NYA    1/5/1966    531    531    531    531        531           0
# 4       NYA    1/6/1966    532    532    532    532        532           0
# ...     ...         ...    ...    ...    ...    ...        ...         ...
# 13943   NYA   5/24/2021  16375  16509  16375  16465      16465  2947400000
# 13944   NYA   5/25/2021  16465  16526  16375  16390      16390  3420870000
# 13945   NYA   5/26/2021  16390  16466  16388  16452      16452  3674490000
# 13946   NYA   5/27/2021  16452  16546  16452  16532      16532  5201110000
# 13947   NYA   5/28/2021  16532  16589  16532  16556      16556  4199270000
#
# [13932 rows x 8 columns]

# %%
# hal baraye sanjeshe min max enheraf meyar tedad va ...discribe mikonim
Data2.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13932.000000  13932.000000  13932.000000  13932.000000  13932.000000
# mean    4456.382142   4473.279859   4437.910996   4456.411570   4456.806273
# std     4074.977658   4095.103590   4052.942082   4075.605456   4075.499391
# min      348.000000    348.000000    348.000000    348.000000    348.000000
# 25%      656.000000    656.000000    656.000000    656.000000    656.000000
# 50%     2634.000000   2634.000000   2634.000000   2634.000000   2634.000000
# 75%     7348.500000   7384.250000   7281.250000   7346.500000   7346.500000
# max    16590.000000  16686.000000  16532.000000  16590.000000  16590.000000
#
#              Volume
# count  1.393200e+04
# mean   1.216874e+09
# std    1.834708e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.685092e+09
# max    1.145623e+10

# %%
#tabdil date be Timeseri

# %%
year = pd.to_datetime(Data2.Date).dt.year
month = pd.to_datetime(Data2.Date).dt.month
day = pd.to_datetime(Data2.Date).dt.day

# %%
Data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13932 entries, 0 to 13947
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Index      13932 non-null  object
#  1   Date       13932 non-null  object
#  2   Open       13932 non-null  int64
#  3   High       13932 non-null  int64
#  4   Low        13932 non-null  int64
#  5   Close      13932 non-null  int64
#  6   Adj Close  13932 non-null  int64
#  7   Volume     13932 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 979.6+ KB

# %%
# hala sotune date ro mibinim beyneshun space hast, banabar in bar asase space dar sotunhaye jodagane gharar midahim
new = Data2["Date"].str.split(" ", n=2, expand=True)    # n=2 yani 2 space ro dar nazar begir va dar 3 sotun bezareshun
# expand=True yani posht sare ham biyareshun, " " yani space beyne kuteyshen ro dar nazar begir
new
# Out:
#                 0
# 0      12/31/1965
# 1        1/3/1966
# 2        1/4/1966
# 3        1/5/1966
# 4        1/6/1966
# ...           ...
# 13943   5/24/2021
# 13944   5/25/2021
# 13945   5/26/2021
# 13946   5/27/2021
# 13947   5/28/2021
#
# [13932 rows x 1 columns]

# %%
# hal mikhahim in formatdate ro az data asli k ba saato inast hazf konim jash traikh ro faghat bezarim
# ebteda formatdate ro drop mikonim ta kamel sotunesh hazf shavad
# yek datafarme jadid dorost mikonim migim dataye mano drop kon az sotune formatdate
Data3=Data2.drop(columns=["Date"])
Data3
# Out:
#       Index   Open   High    Low  Close  Adj Close      Volume
# 0       NYA    529    529    529    529        529           0
# 1       NYA    527    527    527    527        527           0
# 2       NYA    528    528    528    528        528           0
# 3       NYA    531    531    531    531        531           0
# 4       NYA    532    532    532    532        532           0
# ...     ...    ...    ...    ...    ...        ...         ...
# 13943   NYA  16375  16509  16375  16465      16465  2947400000
# 13944   NYA  16465  16526  16375  16390      16390  3420870000
# 13945   NYA  16390  16466  16388  16452      16452  3674490000
# 13946   NYA  16452  16546  16452  16532      16532  5201110000
# 13947   NYA  16532  16589  16532  16556      16556  4199270000
#
# [13932 rows x 7 columns]

# %%
#hala mikham tarikh ro ezafe konam
Data3.insert(0, "Date", new[0], True)    # sefre avali yani avalin sotune dataset biyad(hamun insex),
#dovomi name sotune morede nazar, sevomi migim az new k ghablan sakhtim boro avalik index sefr mishe ro biyar
#Tru ha, bekhatere dorost gharar gereftan hast
Data3
# Out:
#              Date Index   Open   High    Low  Close  Adj Close      Volume
# 0      12/31/1965   NYA    529    529    529    529        529           0
# 1        1/3/1966   NYA    527    527    527    527        527           0
# 2        1/4/1966   NYA    528    528    528    528        528           0
# 3        1/5/1966   NYA    531    531    531    531        531           0
# 4        1/6/1966   NYA    532    532    532    532        532           0
# ...           ...   ...    ...    ...    ...    ...        ...         ...
# 13943   5/24/2021   NYA  16375  16509  16375  16465      16465  2947400000
# 13944   5/25/2021   NYA  16465  16526  16375  16390      16390  3420870000
# 13945   5/26/2021   NYA  16390  16466  16388  16452      16452  3674490000
# 13946   5/27/2021   NYA  16452  16546  16452  16532      16532  5201110000
# 13947   5/28/2021   NYA  16532  16589  16532  16556      16556  4199270000
#
# [13932 rows x 8 columns]

# %%
# agar datahaye 24ruz shabih ham budan migim 23ruzesho hazf kon va faghat yek ruzeh ru dar nazar begir k inja karbord nadare
Data4 = Data3[ : :24]  #satart k az aval bashe, stop k ta akhar bashe, spilit k 24 ruz bashe pas taghsim bandi mishe yek ruze
Data4
# Out:
#              Date Index   Open   High    Low  Close  Adj Close      Volume
# 0      12/31/1965   NYA    529    529    529    529        529           0
# 24       2/3/1966   NYA    532    532    532    532        532           0
# 48      3/10/1966   NYA    511    511    511    511        511           0
# 72      4/14/1966   NYA    525    525    525    525        525           0
# 96      5/18/1966   NYA    486    486    486    486        486           0
# ...           ...   ...    ...    ...    ...    ...        ...         ...
# 13840  12/23/2020   NYA  14397  14457  14397  14399      14399  3772630000
# 13864   1/29/2021   NYA  14670  14670  14328  14397      14397  6612570000
# 13888    3/5/2021   NYA  14959  15284  14819  15252      15252  6842570000
# 13912    4/9/2021   NYA  15887  15956  15866  15956      15956  3634910000
# 13936   5/13/2021   NYA  16043  16243  16035  16182      16182  3687780000
#
# [581 rows x 8 columns]

# %%
Data4.sort_values(by = "Date", inplace=True)     #sort bar asase sotune tarikh anjam she,inplace konesh tu khode Data2
Data4
# Out:
# C:\Users\baraN\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#             Date Index   Open   High    Low  Close  Adj Close      Volume
# 1744   1/10/1973   NYA    688    688    688    688        688           0
# 6040   1/10/1990   NYA   2031   2031   2031   2031       2031           0
# 13096  1/10/2018   NYA  13108  13131  13071  13107      13107  3576350000
# 12592  1/11/2016   NYA   9575   9599   9436   9528       9528  4607290000
# 1240   1/12/1971   NYA    538    538    538    538        538           0
# ...          ...   ...    ...    ...    ...    ...        ...         ...
# 9736    9/7/2004   NYA   6532   6565   6531   6556       6556  1214400000
# ...

# %%
# baraye barresi bazdeh masalan taghirate dama dar 24 ruz bayad ebteda data1 ra sort kard va sepas miyangin gereft
#miyangin yani taghirate 24 ruz ra jam konim va taghsim bar tedade ruzha konim
Df = Data3.sort_values(by="Date")
DataMean = Df.groupby(pd.Grouper(key="Date"), as_index=False).mean()
DataMean
# Out:
#             Date     Open     High      Low    Close  Adj Close        Volume
# 0      1/10/1966    534.0    534.0    534.0    534.0      534.0  0.000000e+00
# 1      1/10/1967    477.0    477.0    477.0    477.0      477.0  0.000000e+00
# 2      1/10/1968    570.0    570.0    570.0    570.0      570.0  0.000000e+00
# 3      1/10/1969    604.0    604.0    604.0    604.0      604.0  0.000000e+00
# 4      1/10/1972    604.0    604.0    604.0    604.0      604.0  0.000000e+00
# ...          ...      ...      ...      ...      ...        ...           ...
# 13927   9/9/2014  10994.0  10994.0  10923.0  10946.0    10946.0  2.882830e+09
# 13928   9/9/2015  10193.0  10220.0   9973.0   9989.0     9989.0  3.652120e+09
# 13929   9/9/2016  10799.0  10799.0  10614.0  10614.0    10614.0  4.233960e+09
# 13930   9/9/2019  12975.0  12975.0  12925.0  12961.0    12961.0  4.002890e+09
# 13931   9/9/2020  12806.0  12969.0  12804.0  12886.0    12886.0  3.920830e+09
#
# [13932 rows x 7 columns]

# %%
#timeseris data va sort v format date

# %%
Data['Date'] = pd.to_datetime(Data['Date'])
Data.sort_values('Date', inplace=True)
date_format = mpl_dates.DateFormatter('%d-%m-%Y')

# %%
#shenasaii noise

# %%
plt.scatter(Data['Open'],Data['Adj Close'], color='green')
plt.xlabel("Open")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("AdjOpen") # zakhireye plat

# %%
#natije = open noise nadasht

# %%
plt.scatter(Data['High'],Data['Adj Close'], color='blue')
plt.xlabel("High")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("AdjHigh") # zakhireye plat

# %%
#natije = High noise nadasht

# %%
plt.scatter(Data['Low'],Data['Adj Close'], color='pink')
plt.xlabel("Low")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("AdjLow") # zakhireye plat

# %%
#natije = Low noise nadasht

# %%
plt.scatter(Data['Close'],Data['Adj Close'], color='orange')
plt.xlabel("Close")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("Adj-Close") # zakhireye plat

# %%
#natije = Close noise dare vali emkane hazfesh nist chon dar mahdudeye khate asli gharar darad

# %%
plt.scatter(Data['Volume'],Data['Adj Close'], color='yellow')
plt.xlabel("Volume")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("AdjVolume") # zakhireye plat

# %%
plt.plot_date(Data['Date'], Data['Adj Close'], linestyle='solid', color='green')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
plt.plot(Data['Date'], Data['Adj Close'], linestyle='solid', color='green')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
plt.plot(Data['Date'], Data['Close'], linestyle='solid', color='blue')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Close')
plt.show()

# %%
plt.plot(Data['Date'], Data['Low'], linestyle='solid', color='yellow')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Low')
plt.show()

# %%
plt.plot(Data['Date'], Data['Low'], linestyle='solid', color='yellow')
plt.plot(Data['Date'], Data['High'], linestyle='solid', color='orange')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('High-Low')
plt.show()

# %%
plt.plot(Data['Date'], Data['Open'], linestyle='solid', color='pink')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Open')
plt.show()

# %%
plt.plot(Data['Date'], Data['High'], linestyle='solid', color='orange')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('High')
plt.show()

# %%
plt.plot(Data['Date'], Data['Volume'], linestyle='solid', color='red')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %%
plt.scatter(Data['Open'],Data['Close'], color='green')
plt.xlabel("Open")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("Openclose") # zakhireye plat

# %%
plt.scatter(Data['Adj Close'],Data['Close'], color='green')
plt.xlabel("Adj Close")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("Adj Close-close") # zakhireye plat

# %%
plt.plot(Data['Adj Close'],Data['Close'], color='green')
plt.xlabel("Adj Close")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("Adj Close-close") # zakhireye plat

# %%
plt.scatter(Data['Volume'],Data['Adj Close'], color='yellow')
plt.xlabel("Volume")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("Adj Close-Volume") # zakhireye plat

# %%
plt.scatter(Data['Low'],Data['Adj Close'], color='green')
plt.xlabel("Low")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("Adj Close-Low") # zakhireye plat

# %%
#natije= volume daraye noise ast : x<6.5

# %%
#noise = faghat volume noise dasht

# %%
# bad az shenasaii noise mising valuhara delete mikonim

# %%
Data5 = Data4.dropna()
Data5
# Out:
#             Date Index   Open   High    Low  Close  Adj Close      Volume
# 1744   1/10/1973   NYA    688    688    688    688        688           0
# 6040   1/10/1990   NYA   2031   2031   2031   2031       2031           0
# 13096  1/10/2018   NYA  13108  13131  13071  13107      13107  3576350000
# 12592  1/11/2016   NYA   9575   9599   9436   9528       9528  4607290000
# 1240   1/12/1971   NYA    538    538    538    538        538           0
# ...          ...   ...    ...    ...    ...    ...        ...         ...
# 9736    9/7/2004   NYA   6532   6565   6531   6556       6556  1214400000
# 10744   9/8/2008   NYA   8034   8242   8034   8169       8169  7351340000
# 11248   9/8/2010   NYA   6960   7034   6960   7000       7000  3224640000
# 2416    9/9/1975   NYA    476    476    476    476        476           0
# 12760   9/9/2016   NYA  10799  10799  10614  10614      10614  4233960000
#
# [581 rows x 8 columns]

# %%
# hal baraye sanjeshe min max enheraf meyar tedad va ...discribe mikonim
Data4.describe()
# Out:
#               Open          High           Low         Close     Adj Close  \
# count    581.00000    581.000000    581.000000    581.000000    581.000000
# mean    4442.69191   4460.363167   4425.022375   4445.072289   4445.072289
# std     4062.61686   4085.571581   4042.360761   4067.271816   4067.271816
# min      370.00000    370.000000    370.000000    370.000000    370.000000
# 25%      656.00000    656.000000    656.000000    656.000000    656.000000
# 50%     2632.00000   2632.000000   2632.000000   2632.000000   2632.000000
# 75%     7378.00000   7408.000000   7335.000000   7394.000000   7394.000000
# max    16043.00000  16243.000000  16035.000000  16182.000000  16182.000000
#
#              Volume
# count  5.810000e+02
# mean   1.233514e+09
# std    1.876569e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.785290e+09
# max    1.145623e+10

# %%
#barresi inke bebinim missing valueha be tore koli hazf shode ast va digar missing valu nadarad
print ("\n show the missing values of DataFrame : \n\n", Data4.isnull().sum())
# Out:
#  show the missing values of DataFrame :
#
#  Date         0
# Index        0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# hazfe noiseha

# %%
small = Data["Volume"].nsmallest(3)
small
# Out:
# 92450    0.0
# 92451    0.0
# 92452    0.0
# Name: Volume, dtype: float64

# %%
Data6 = Data5[Data5["Volume"]<6.5]
Data6
# Out:
#            Date Index  Open  High   Low  Close  Adj Close  Volume
# 1744  1/10/1973   NYA   688   688   688    688        688       0
# 6040  1/10/1990   NYA  2031  2031  2031   2031       2031       0
# 1240  1/12/1971   NYA   538   538   538    538        538       0
# 5536  1/13/1988   NYA  1459  1459  1459   1459       1459       0
# 5032  1/15/1986   NYA  1270  1270  1270   1270       1270       0
# ...         ...   ...   ...   ...   ...    ...        ...     ...
# 662    9/5/1968   NYA   596   596   596    596        596       0
# 3424   9/5/1979   NYA   641   641   641    641        641       0
# 172    9/6/1966   NYA   440   440   440    440        440       0
# 2920   9/7/1977   NYA   567   567   567    567        567       0
# 2416   9/9/1975   NYA   476   476   476    476        476       0
#
# [367 rows x 8 columns]

# %%
#small = Data["Volume"].nsmallest(3)
#small
# Out:
# 92450    0.0
# 92451    0.0
# 92452    0.0
# Name: Volume, dtype: float64

# %%
#Data7 = Data5[Data5["Volume"]<"1999/01/01"]
#Data7

# %%
plt.plot(Data6['Open'],Data6['Adj Close'], color='green')
plt.xlabel("Open")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("AdjOpen") # zakhireye plat

# %%
plt.plot(Data5['Open'],Data5['Adj Close'], color='green')
plt.xlabel("Open")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("NYA")
plt.savefig("AdjOpen") # zakhireye plat

# %%
plt.plot(Data6['High'],Data6['Adj Close'], color='green')
plt.xlabel("High")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("Shakhes_NYA")
plt.savefig("AdjHigh") # zakhireye plat

# %%
plt.plot(Data5['High'],Data5['Adj Close'], color='green')
plt.xlabel("High")    #baraye bordare x miyaym onvan ghrar midhim
plt.xticks (rotation=90)
plt.ylabel("Adj Close")    #baraye bordare y miyaym onvan ghrar midhim
plt.grid()                # grid bandi kardan nemudar
plt.title("Shakhes_NYA")
plt.savefig("AdjHigh") # zakhireye plat

# %%
Data5['Date'] = pd.to_datetime(Data5['Date'])
Data5.sort_values('Date', inplace=True)
date_format = mpl_dates.DateFormatter('%d-%m-%Y')

# %%
Data6['Date'] = pd.to_datetime(Data6['Date'])
Data6.sort_values('Date', inplace=True)
date_format = mpl_dates.DateFormatter('%d-%m-%Y')
# Out:
# C:\Users\baraN\AppData\Local\Temp/ipykernel_2200/1413804022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data6['Date'] = pd.to_datetime(Data6['Date'])
# C:\Users\baraN\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
#Axis: yek dataframe daraye  axis(mehvar ya boed) ast, axis0:satr v axis1:sotun
#gca:mehvar feli ra gerefte va meghdare un ra bar migardanad.set kardan format
# plt.tight_layout() :tanzim parametrhaye faree(فرعی),parametrhaye mehvar x v y k birun nazanad az safhe
#gcf:bozorgtarin amele moshtarak

# %%
#Data['Date'] = pd.to_datetime(Data['Date'])
#Data.sort_values('Date', inplace=True)
plt.plot_date(Data6['Date'], Data6['Adj Close'], linestyle='solid')
plt.gcf().autofmt_xdate()
#date_format = mpl_dates.DateFormatter('%d-%m-%Y')
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
plt.plot_date(Data5['Date'], Data5['Adj Close'], linestyle='solid')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
plt.plot(Data6['Date'], Data6['Adj Close'], linestyle='solid', color='green')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%d-%m-%Y')
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Adj Close'], linestyle='solid', color='blue')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Close'], linestyle='solid', color='green')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Close')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Open'], linestyle='solid', color='orange')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Open')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['High'], linestyle='solid', color='red')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('High')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Low'], linestyle='solid', color='yellow')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Low')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Volume'], linestyle='solid', color='pink')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %%
plt.plot(Data6['Date'], Data6['Volume'], linestyle='solid')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %%
#feature volume ra hazf konim behtare chon bahazfe noise in feature hajme ziyadi az dadeha az beyn miravad.
# pas behtare kolan feature volume hazf shavad.

# %%
plt.plot(Data5['Date'], Data5['Adj Close'], linestyle='solid', color='green')
plt.plot(Data5['Date'], Data5['Open'], linestyle='solid', color='blue')
plt.plot(Data5['Date'], Data5['Close'], linestyle='solid', color='orange')
plt.plot(Data5['Date'], Data5['High'], linestyle='solid', color='yellow')
plt.plot(Data5['Date'], Data5['Low'], linestyle='solid', color='red')
plt.plot(Data5['Date'], Data5['Volume'], linestyle='solid', color='pink')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(Data['Date'], Data['Adj Close'], linestyle='solid', color='green')
plt.plot(Data['Date'], Data['Open'], linestyle='solid', color='blue')
plt.plot(Data['Date'], Data['Close'], linestyle='solid', color='orange')
plt.plot(Data['Date'], Data['High'], linestyle='solid', color='yellow')
plt.plot(Data['Date'], Data['Low'], linestyle='solid', color='red')
plt.plot(Data['Date'], Data['Volume'], linestyle='solid', color='pink')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Adj Close'], linestyle='solid', color='green')
plt.plot(Data5['Date'], Data5['Close'], linestyle='solid', color='orange')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Adj Close'], linestyle='solid', color='green')
plt.plot(Data5['Date'], Data5['Open'], linestyle='solid', color='orange')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Adj Close'], linestyle='solid', color='blue')
plt.plot(Data5['Date'], Data5['Low'], linestyle='solid', color='orange')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['Adj Close'], linestyle='solid', color='green')
plt.plot(Data5['Date'], Data5['High'], linestyle='solid', color='orange')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(Data5['Date'], Data5['High'], linestyle='solid', color='green')
plt.plot(Data5['Date'], Data5['Low'], linestyle='solid', color='orange')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
DataMean['Date'] = pd.to_datetime(DataMean['Date'])
DataMean.sort_values('Date', inplace=True)
date_format = mpl_dates.DateFormatter('%d-%m-%Y')

# %%
plt.plot(DataMean['Date'], DataMean['Adj Close'], linestyle='solid')
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.title('Shakhes_NYA')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()
